# %%
import logging
logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)
# create a logger for moudule2
logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

# Configure logging settings
logging.basicConfig(
level=logging.DEBUG,
format='%(asctime)s -%(name)s -%(levelname)s -%(message)s',
datefmt='%Y-%m-%d %H :%M:%S')

# %%
## log messages for different loggers
logger1.debug("This is a debug message from module1")
logger1.info("This is an info message from module1")
logger1.warning("This is a warning message from module1")
logger2.debug("This is a debug message from module2")
logger2.info("This is an info message from module2")
logger2.warning("This is a warning message from module2")
# Out:
# 2025-12-23 16 :25:24 -module1 -DEBUG -This is a debug message from module1
# 2025-12-23 16 :25:24 -module1 -INFO -This is an info message from module1
# 2025-12-23 16 :25:24 -module1 -WARNING -This is a warning message from module1
# 2025-12-23 16 :25:24 -module2 -WARNING -This is a warning message from module2
